# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhitarani439/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 16:11:43--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   139MB/s    in 0.5s
#
# 2024-03-25 16:11:44 (139 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6963   1708.02666v1  This is the Proceedings of the 2017 ICML Works...  stat
# 8712   1801.01453v1  The k-Nearest Neighbor (kNN) classification ap...    cs
# 28511  1706.09180v2  This paper introduces a new real-time object d...    cs
# 22791  1706.08984v1  Learning by children and animals occurs effort...  stat
# 40209  1801.08863v1  This paper provides an overview of 3D scanning...    cs
# ...             ...                                                ...   ...
# 12499  1802.05814v1  We extend variational autoencoders (VAEs) to c...  stat
# 22398  1605.07906v2  The hyperparameters in Gaussian process regres...  stat
# 2169   1701.08810v3  This paper formalises the problem of online al...  stat
# 33477   1302.5474v2  The ability to track the optimum of dynamic en...    cs
# 9361   1507.00996v2  We introduce and demonstrate a new approach to...  stat
#
#                                                    title  year  \
# 6963   Proceedings of the 2017 ICML Workshop on Human...  2017
# 8712   Adaptive kNN using Expected Accuracy for Class...  2017
# 28511  Yes-Net: An effective Detector Based on Global...  2017
# 22791  Unsupervised Learning via Total Correlation Ex...  2017
# 40209                3D Scanning: A Comprehensive Survey  2018
# ...                                                  ...   ...
# 12499  Variational Autoencoders for Collaborative Fil...  2018
# 22398  How priors of initial hyperparameters affect G...  2016
# 2169          Reinforcement Learning Algorithm Selection  2017
# 33477  On the performance of a hybrid genetic algorit...  2013
# 9361   A New Approach to Probabilistic Programming In...  2015
#
#                                                 keywords
# 6963   [proceedings, interpretability, australia, pro...
# 8712   [classification, conceptually, practical, appl...
# 28511  [introduces, detection, prediction, efficient,...
# 22791  [effortlessly, supervision, successes, automat...
# 40209  [methodologies, technologies, scientific, indu...
# ...                                                  ...
# 12499  [variational, autoencoders, collaborative, fil...
# 22398  [hyperparameters, regression, specified, estim...
# 2169   [formalises, algorithm, selection, reinforceme...
# 33477  [environments, important, practical, applicati...
# 9361   [introduce, demonstrate, inference, expressive...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6963     [proceedings, interpretability, australia, pro...
# 8712     [classification, conceptually, practical, appl...
# 28511    [introduces, detection, prediction, efficient,...
# 22791    [effortlessly, supervision, successes, automat...
# 40209    [methodologies, technologies, scientific, indu...
#                                ...
# 24570    [withdrawn, information, information, recognit...
# 11007    [predictor, production, predictions, fulfillin...
# 5532     [knowledge, incorporated, algorithm, effective...
# 5016     [algorithms, combinatorial, stochasticity, var...
# 22832    [introduce, algorithm, approximate, inference,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8719 words.
# Out of those 4513 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c90d6229-21ca-4dd2-899c-fe1fc3c73ba3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c90d6229-21ca-4dd2-899c-fe1fc3c73ba3")) {                    Plotly.newPlot(                        "c90d6229-21ca-4dd2-899c-fe1fc3c73ba3",                        [{"x":["proceedings","interpretability","introduce","introduced","previously","presented","distribution","classified","conceptually","classifier","practical","arbitrary","estimator","significantly","maximized","evaluation","demonstrate","considered","influence","outperforms","irregular","algorithm","performance","similarity","thousands","algorithms","classification","structurally","dynamically","observations","functions","different","applications","introduces","effective","outstanding","efficient","detection","dimension","independent","information","extractor","prediction","architecture","multivariate","dependence","suggested","ambiguous","representations","unsupervised","supervised","explanation","successes","translated","redundancy","manifestations","effortlessly","including","correlation","environment","characterized","principle","automating","supervision","theoretic","industrial","processing","techniques","comparison","literature","procedures","methodologies","throughout","reliability","concisely","structured","scientific","technologies","necessary","comparative","discussed","distinction","comprehensive","terrestrial","combinational","structure","relevance","emissions","dependent","construction","parameters","transitions","inferring","motivated","estimating","variations","recognition","improvements","variation","approaches","scenarios","significant","representation","challenges","utilizing","benchmarks","optimizes","traditional","researched","contribute","component","linguistic","characteristics","segmentation","particular","thoroughly","dictionaries","eliminate","reasonable","intractable","available","phenomenon","supported","international","ambiguity","efficiency","complementary","languages","minimization","satisfied","compressed","minimizing","overlapping","generalized","restricted","satisfies","universal","decomposable","sufficiently","following","minimized","specifically","compressibility","components","directions","condition","optimization","approximate","parameter","linearization","lightweight","asymptotically","asymptotic","quadratic","sometimes","estimation","converges","stochastic","arbitrarily","discovering","innovation","realistic","typological","induction","adjectives","synthetic","correlate","syntactic","collection","properties","engineered","dependency","experiment","relations","sequences","competitive","theoretical","establish","effectively","modification","simulation","denoising","construct","experiments","conventional","laplacian","regularization","processes","application","predictive","knowledge","incorporate","transform","addressing","characterizations","investigate","contribution","correspond","nonlinearities","attractive"],"y":[7,17,311,122,83,174,193,22,14,158,144,77,28,267,3,257,591,138,59,263,14,831,886,145,29,610,462,8,29,67,211,753,417,75,252,9,402,334,60,133,700,13,232,260,17,25,27,22,239,161,193,21,16,19,20,1,1,242,87,107,29,59,7,56,51,22,301,364,139,117,42,13,15,29,3,111,36,29,71,35,51,8,55,2,3,348,43,2,79,63,269,20,28,61,55,77,376,112,60,436,86,232,362,115,42,104,20,185,3,23,100,77,76,215,274,14,19,13,28,33,310,15,20,19,20,167,30,99,70,11,23,54,27,66,48,21,39,1,21,97,11,167,1,107,49,39,321,111,126,3,11,14,13,30,33,192,25,115,14,16,7,57,5,25,4,136,10,53,74,226,8,44,74,100,104,115,132,46,137,32,76,36,91,630,96,16,72,105,239,58,382,59,51,27,3,133,70,23,3,16],"type":"bar"},{"x":["proceedings","interpretability","introduce","introduced","previou ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4513,), (4513, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimizing</span> <span style=''>the</span> <span style=''>Learning</span> <span style=''>Order</span> <span style=''>of</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.8285714285714286);'>Characters</span> <span style=''>Using</span> <span style=''>a</span> <span style=''>Novel</span> <span style='background-color:rgba(0, 255, 0, 0.35483870967741943);'>Topological</span> <span style=''>Sort</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>the</span> <span style=''>order</span> <span style=''>in</span> <span style=''>which</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.8285714285714286);'>characters</span> <span style=''>are</span> <span style=''>learned</span> <span style=''>one</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporates</span> <span style=''>the</span> <span style=''>benefits</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>them</span> <span style=''>in</span> <span style=''>order</span> <span style=''>of</span> <span style=''>usage</span> <span style='background-color:rgba(0, 255, 0, 0.425531914893617);'>frequency</span> <span style=''>and</span> <span style=''>in</span> <span style=''>order</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>hierarchal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>work</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperforms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>published</span> <span style=''>orders</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.4838709677419356);'>scheduling</span> <span style=''>task</span> <span style=''>where</span> <span style=''>nodes</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differences</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>and</span> <span style=''>must</span> <span style=''>be</span> <span style=''>visited</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.35483870967741943);'>topological</span> <span style=''>order</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MDL</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <span style=''>of</span> <span style=''>GLM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increases</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>and</span> <span style=''>retains</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>power</span> <br/><br/><span style=''>Over</span> <span style=''>the</span> <span style=''>years</span> <span style=''>ensemble</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>become</span> <span style=''>a</span> <span style=''>staple</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Similarly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>(GLMs)</span> <span style=''>have</span> <span style=''>become</span> <span style=''>very</span> <span style=''>popular</span> <span style=''>for</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>tasks</span> <span style=''>The</span> <span style=''>former</span> <span style=''>have</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>enhance</span> <span style=''>out</span> <span style=''>of</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>power</span> <span style=''>and</span> <span style=''>the</span> <span style=''>latter</span> <span style=''>possess</span> <span style=''>easy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>Recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>of</span> <span style=''>GLMs</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>possibility</span> <span style=''>On</span> <span style=''>the</span> <span style=''>downside</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>loses</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>that</span> <span style=''>GLMs</span> <span style=''>possess</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>minimum</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>description</span> <span style=''>length</span> <span style=''>(MDL)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <span style=''>of</span> <span style=''>the</span> <span style=''>inferred</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>recover</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>without</span> <span style=''>much</span> <span style=''>if</span> <span style=''>any</span> <span style=''>downside</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> <span style=''>on</span> <span style=''>a</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Value</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>via</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>models</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>value</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>Markov</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compactly</span> <span style='background-color:rgba(0, 255, 0, 0.35555555555555557);'>representing</span> <span style=''>the</span> <span style=''>state</span> <span style=''>action</span> <span style=''>value</span> <span style=''>function</span> <span style=''>using</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>sparse</span> <span style=''>matrix</span> <span style=''>model</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decompose</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>that</span> <span style=''>encodes</span> <span style=''>the</span> <span style=''>true</span> <span style=''>value</span> <span style=''>function</span> <span style=''>into</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>and</span> <span style=''>we</span> <span style=''>achieve</span> <span style=''>this</span> <span style=''>using</span> <span style=''>Robust</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>(PCA)</span> <span style=''>Under</span> <span style=''>minimal</span> <span style='background-color:rgba(255, 0, 0, 0.3271889400921658);'>assumptions</span> <span style=''>this</span> <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style=''>solved</span> <span style=''>exactly</span> <span style=''>via</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Pursuit</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3962264150943397);'>experiment</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>on</span> <span style=''>several</span> <span style=''>examples</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>yields</span> <span style='background-color:rgba(255, 0, 0, 0.4126984126984127);'>approximations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>essentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identical</span> <span style=''>to</span> <span style=''>the</span> <span style=''>true</span> <span style=''>function</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Hierarchical</span> <span style=''>Memory</span> <span style=''>Networks</span> <br/><br/><span style=''>Memory</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>an</span> <span style=''>explicit</span> <span style=''>memory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>both</span> <span style=''>read</span> <span style=''>and</span> <span style=''>written</span> <span style=''>to</span> <span style=''>by</span> <span style=''>the</span> <span style=''>network</span> <span style=''>The</span> <span style=''>memory</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressed</span> <span style=''>in</span> <span style=''>a</span> <span style=''>soft</span> <span style=''>way</span> <span style=''>using</span> <span style=''>a</span> <span style=''>softmax</span> <span style=''>function</span> <span style=''>making</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>training</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>backpropagation</span> <span style=''>possible</span> <span style=''>However</span> <span style=''>this</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style=''>scalable</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>which</span> <span style=''>require</span> <span style=''>the</span> <span style=''>network</span> <span style=''>to</span> <span style=''>read</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extremely</span> <span style=''>large</span> <span style=''>memories</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>it</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>hard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanisms</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>to</span> <span style=''>train</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>a</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style=''>memory</span> <span style=''>network</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>as</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>between</span> <span style=''>hard</span> <span style=''>and</span> <span style=''>soft</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>memory</span> <span style=''>networks</span> <span style=''>The</span> <span style=''>memory</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>organized</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10468024294390854)
# 	representation (0.1293319042515184)
# 	segmentation (0.07681314755269739)
# 	architecture (0.09289031797070382)
# 	detection (0.11932833154698107)
# 	knowledge (0.13647731332618793)
# 	information (0.2500893176134334)
# 	different (0.2690246516613076)
# 	recognition (0.13433369060378705)
# 	convolutional (0.1382636655948553)
#
# Some Statistics words are:
# 	algorithm (0.383808095952024)
# 	statistical (0.1519240379810095)
# 	theoretical (0.1409295352323838)
# 	variables (0.14142928535732133)
# 	stochastic (0.1424287856071964)
# 	estimation (0.1724137931034483)
# 	inference (0.20339830084957522)
# 	distribution (0.1924037981009495)
# 	regression (0.1744127936031984)
# 	dimensional (0.18990504747626186)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="60cdcfe1-fe84-4d33-919c-b90069964c2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60cdcfe1-fe84-4d33-919c-b90069964c2a")) {                    Plotly.newPlot(                        "60cdcfe1-fe84-4d33-919c-b90069964c2a",                        [{"x":["proceedings","interpretability","introduce","introduced","previously","presented","distribution","classified","conceptually","classifier","practical","arbitrary","estimator","significantly","maximized","evaluation","demonstrate","considered","influence","outperforms","irregular","algorithm","performance","similarity","thousands","algorithms","classification","structurally","dynamically","observations","functions","different","applications","introduces","effective","outstanding","efficient","detection","dimension","independent","information","extractor","prediction","architecture","multivariate","dependence","suggested","ambiguous","representations","unsupervised","supervised","explanation","successes","translated","redundancy","manifestations","effortlessly","including","correlation","environment","characterized","principle","automating","supervision","theoretic","industrial","processing","techniques","comparison","literature","procedures","methodologies","throughout","reliability","concisely","structured","scientific","technologies","necessary","comparative","discussed","distinction","comprehensive","terrestrial","combinational","structure","relevance","emissions","dependent","construction","parameters","transitions","inferring","motivated","estimating","variations","recognition","improvements","variation","approaches","scenarios","significant","representation","challenges","utilizing","benchmarks","optimizes","traditional","researched","contribute","component","linguistic","characteristics","segmentation","particular","thoroughly","dictionaries","eliminate","reasonable","intractable","available","phenomenon","supported","international","ambiguity","efficiency","complementary","languages","minimization","satisfied","compressed","minimizing","overlapping","generalized","restricted","satisfies","universal","decomposable","sufficiently","following","minimized","specifically","compressibility","components","directions","condition","optimization","approximate","parameter","linearization","lightweight","asymptotically","asymptotic","quadratic","sometimes","estimation","converges","stochastic","arbitrarily","discovering","innovation","realistic","typological","induction","adjectives","synthetic","correlate","syntactic","collection","properties","engineered","dependency","experiment","relations","sequences","competitive","theoretical","establish","effectively","modification","simulation","denoising","construct","experiments","conventional","laplacian","regularization","processes","application","predictive","knowledge","incorporate","transform","addressing","characterizations","investigate","contribution","correspond","nonlinearities","attractive","optimizers","nonlinearity","inclusion","occurrence","occasionally","discovered","completely","solutions","extensively","understood","distributions","relationship","iterative","interested","community","cluttered","synthesis","posterior","occlusion","likelihood","background","improvement","appearances","observation","empirically","difficulties","difficult","successful","describing","complicated","backgrounds","specialize","appearance","convolutional","meaningful","collaborative","expressed","disregard","vocabulary","individual","generative","recommendation","preferences","filtering","evolution","recommending","recommender","dirichlet","substantial","baselines","similarities","interests","observables","experience","recommendations"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	detectability
# 	couplings
# 	spherically
# 	assortativity
# 	stabilisation
# 	disability
# 	gaussianity
# 	unavailability
# 	pessimistic
# 	illustrations
# 	penalizations
# 	thermostats
# 	covariates
# 	activates
# 	stratified
# 	unattainable
# 	infectious
# 	phenotypes
# 	spectrometry
# 	eigendecomposition
# Some words which never appear in Statistics papers:
# 	terrestrial
# 	combinational
# 	typological
# 	adjectives
# 	syntactic
# 	appearances
# 	recommending
# 	progressing
# 	discourse
# 	histological
# 	photograph
# 	establishment
# 	affective
# 	cambridge
# 	disambiguation
# 	quantizations
# 	subsequence
# 	superiorly
# 	certification
# 	humanities

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0766390794695876e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
